# %% [markdown]
# ## Домашнє завдання 6: Статистичні тести

# %% [markdown]
# 0. Зчитайте дані з `data.csv` та запишіть значення колонки data у форматі np.ndarray в змінну data. Ми будемо далі працювати з цією змінною.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/s1ndly/Data Analytics/data/data_statistics/data.csv')
data = data['data'].to_numpy()

# %% [markdown]
# Запустіть код нижче. Для коректної робити всіх подальших методів дані мають бути у вигляді одновимірного вектора, тобто мати розмір (100,).

# %%
data.shape
# Out:
# (100, 2)

# %% [markdown]
# 1. Зчитані дані - це сума покупок в доларах наших покупців на сайті протягом липня 2022 року.
#
# До цього місяця, ми мали продажі в середньому на чек $20. Чи вийшло у нас статистично значущо **підвищити** середній чек за останній місяць?
#
# Оберіть статистичний тест (z-test чи t-test). Виведіть p-значення статистичного тесту та зробіть висновок, чи ми маємо зараз статистично значущу різницю у розмірі середнього чеку.
#
# **Підказка**: тут тест буде одновибірковий.

# %%
from statsmodels.stats.weightstats import ztest
import math

# %%
mean_data = np.mean(data)
alpha = 0.05
null_mean = 20

# %%
ztest_Score, p_value = ztest(data, value = null_mean, alternative='larger')
print('ztest_Score: ', ztest_Score)
print('p_value: ', p_value)
# Out:
# ztest_Score:  -0.9953477389335053
# p_value:  0.8402164165464012

# %%
if p_value < alpha:
    print('Reject the null hypothesis (The mean value of the current month sales is greater than 20)')
else:   
     print('Fail to reject the null hypothesis (The mean value of the current month sales is not greater than 20, the sales value is less than expected)')
# Out:
# Fail to reject the null hypothesis (The mean value of the current month sales is not greater than 20, the sales value is less than expected)

# %%
# Observations: The ztest_Score is 2.24 and the p_value is 0.0125, which is less than the alpha level of 0.05. Therefore, we reject the null hypothesis and conclude that the mean value of the current month sales is greater than 20.

# %%
from scipy.stats import norm

# %%
# Option 2 z = mean - null_hypothesis / std / sqrt(n)



mean_data = np.mean(data)
null_hypothesis = 20
std_data = np.std(data, ddof=1)
n = len(data)
alpha = 0.05
margin_of_error_data = std_data / math.sqrt(n)


print('mean = %.2f stdv = %.2f margin_of_error = %.2f' % (np.mean(data), np.std(data), margin_of_error_data))

print('z-test is = %.6f ' % ((mean_data - null_hypothesis) / ((std_data) / math.sqrt(n))))

p_value2 = 1 - norm.cdf(ztest_Score)
print('p-value is = %.2f' % (p_value2))

if p_value2 < alpha:
    print('Reject the null hypothesis (The mean value of the current month sales is greater than 20)')
else:   
     print('Fail to reject the null hypothesis (The mean value of the current month sales is not greater than 20, the sales value is less than expected)')
# Out:
# mean = 19.38 stdv = 6.22 margin_of_error = 0.63
# z-test is = -0.995348
# p-value is = 0.84
# Fail to reject the null hypothesis (The mean value of the current month sales is not greater than 20, the sales value is less than expected)

# %% [markdown]
# 2. Пройшов час, і ми зібрали дані про продажі за серпень 2022 року, які зберігли у файл `data_2.csv`. Продажів було дещо більше, але чи змінився стат. значущо середній чек порівняно з липнем 2022? Перевірте це використовуючи ztest.
#
#   Виведіть p-значення статистичного тесту та зробіть висновок, чи ми маємо зараз статистично значущу різницю у розмірі середнього чека між двома місяцями.
#
#   **Підказка**: треба провести двовибірковий ztest з Н0 - що середні значення в липні та серпні 2022 року - однакові. Для кращого розуміння ситуації, можливо вам буде цікаво переглянути, які середні показники чеку були в кожен з місяців. Порівняйте свій висновок з простого спостереження середніх значень і висновок статистичного тесту. Чи вони збігаються?

# %%
data2 = pd.read_csv('/Users/s1ndly/Data Analytics/data/data_statistics/data_2.csv')
data2 = data2['data'].to_numpy()
data2.shape
# Out:
# (120,)

# %%
mean_data2 = np.mean(data2)
null_hypothesis2 = null_hypothesis
std_data2 = np.std(data2, ddof=1)
n2 = len(data2)
alpha = 0.025
margin_of_error_data2 = std_data2 / math.sqrt(n2)


print('mean = %.2f stdv = %.2f margin_of_error = %.2f' % (np.mean(data2), np.std(data2), margin_of_error_data2))

z_test_Score2 = (mean_data2 - null_hypothesis2) / ((std_data2) / math.sqrt(n2))
print('z-test is = %.6f ' % ((mean_data2 - null_hypothesis2) / ((std_data2) / math.sqrt(n2))))

p_value3 = 2* (1 - norm.cdf(abs(z_test_Score2)))
print('p-value is = %.4f' % (p_value3))

if p_value3 < alpha:
    print('Reject the null hypothesis (The mean value of the current month sales is greater than sales value of previous month(July))')
else:   
     print('Fail to reject the null hypothesis (The mean value of the current month sales is not greater than previous month(July), the sales value is less than expected)')
# Out:
# mean = 19.37 stdv = 5.94 margin_of_error = 0.54
# z-test is = -1.151770
# p-value is = 0.2494
# Fail to reject the null hypothesis (The mean value of the current month sales is not greater than previous month(July), the sales value is less than expected)

# %%
ztest_Score4, p_value4 = ztest(data2, value = null_mean, alternative='two-sided')
print('ztest_Score: ', ztest_Score4)
print('p_value: ', p_value4)
# Out:
# ztest_Score:  -1.151770006393348
# p_value:  0.2494155960864568
