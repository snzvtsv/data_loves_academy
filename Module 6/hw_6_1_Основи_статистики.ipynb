# %% [markdown]
# В цьому домашньому завданні відпрацюємо з вами знання, отримані в модулі зі статистики.
#
# **Завдання 1.** Ми обговорили з Вами на лекції, що велика літера Сігма грецького алфавіту позначає в математиці суму. Знайдіть з використанням Python $\Sigma x$, $\Sigma x^2$, та $\Sigma (x-1)^2$ для наступного набору даних:
# `1 3 4`
# Виведіть результат кожного обчислення на екран.

# %%
import numpy as np

# %%
x = [1, 3, 4]

# %%
sum_x = sum(x)
sqr_sum_x = sum([i**2 for i in x])
sqr_sum_x_minus_1 = sum([(i-1)**2 for i in x])

# %%
sum_x, sqr_sum_x, sqr_sum_x_minus_1
# Out:
# (8, 26, 13)

# %% [markdown]
# **Завдання 2.** Ми зібрали дані про суму покупок в гривнях 20ма випадково обраними клієнтами в нашому магазині (всього клієнтів у нас більше) за минулий місяць. Вони представлені в змінній `sum_purchases`. Знайдіть **вибіркове середнє** для цих даних кожним з зазначених методів:
#
#   2.1. без використання жодних бібліотек, користуючись тільки Python.
#   2.2. використовуючи відповідний метод бібліотеки `numpy`.
#
#   Виведіть результат обчислень в кожному з випадків на екран та порівняйте результати. Вони співпадають?

# %%
sum_purchases = [ 316,  493,  367,  153,  224,  121,  322,  450,  196,  397,  281,
  239,  484,  124,  223,  448,  432,  255, 4310, 3524]

# %%
mean_purchases = sum(sum_purchases) / len(sum_purchases)
mean_purchases
# Out:
# 667.95

# %%
np.mean(sum_purchases)
# Out:
# 667.95

# %% [markdown]
# **Завдання 3.** Для того ж набору даних в змінній `sum_purchases` обчисліть **медіану** кожним з зазначених методів:
#
#   3.1. без використання жодних бібліотек, користуючись тільки Python.
#   3.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран. Порівняйте результати зі значенням вибіркового середнього. Напишіть коментар, для яких задач ви б використовували вибіркове середнє, а для яких - медіану?

# %%
(sorted(sum_purchases)[len(sum_purchases)//2] + sorted(sum_purchases)[len(sum_purchases)//2 - 1]) / 2
# Out:
# 319.0

# %%
np.median(sum_purchases)
# Out:
# 319.0

# %% [markdown]
# Median for large datasets with assymetric distribution (not normal data) of data that can be used in finance, statistics, population. Also, when we have outliers and we would like to avoid their influence.

# %% [markdown]
# **Завдання 4**. Обчислість стандартне відхилення наведеної вибірки в змінній `sum_purchases` кожним з зазначених методів:
#
#   4.1. без використання жодних бібліотек, користуючись тільки Python.
#   4.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат обчислень в кожному з випадків на екран.

# %%
sqr_sum_minus_mean = [(i - mean_purchases)**2 for i in sum_purchases]
var_sum_purchases = sum(sqr_sum_minus_mean) / len(sum_purchases)
var_sum_purchases
# Out:
# 1201367.8475000001

# %%
np.var(sum_purchases)
# Out:
# 1201367.8475000001

# %% [markdown]
# **Завдання 5**. Ми провели дослідження віку студентів-першокурсників. Виявилось, що
# - 10 студентів мають вік 16 років
# - 25 студентів - 17 років
# - 20 студентів - 18 років
# - 2 студенти - 20 років
#
# Обчислість середнє значення для цієї вибірки будь-яким способом - на чистому Python або з numpy - та виведіть результат на екран.

# %%
mena_ages = [int(age) for age, count in students_age.items() for _ in range(count)]
np.mean(mena_ages)
# Out:
# 17.280701754385966

# %%
students_age = { '16' : 10,
                '17': 25,
                '18': 20,
                '20': 2
                }

np.average(list(int(age) for age in students_age.keys()), weights=list(students_age.values()))
# Out:
# 17.280701754385966

# %%
np.average(list(map(int, students_age.keys())), weights=list(students_age.values()))
# Out:
# 17.280701754385966

# %% [markdown]
# **Завдання 6**. Крім даних про суму покупок, ми зібрали ще дані про кількість відвідувань кожного з кожного покупця, які знаходяться в змінній `visits`. Обчисліть коефіцієнт кореляції Пірсона для суми покупок і кількості відвідувань кожним з зазначених методів:
#
#   6.1. без використання жодних бібліотек, користуючись тільки Python.
#   6.2. використовуючи відповідний метод бібліотеки numpy.
#
# Виведіть результат на екран. Проаналізуйте результат.
#
# Виведіть додатково графік розсіювання викликавши код нижче і зробіть заключення, чи варто щось змінити при підрахунку кореляції, аби коефіцієнт Пірсона показував коректну оцінку лінійної залежності?

# %%
visits = [ 6,  2, 10,  3,  9,  9,  2,  3,  6,  6, 10,  2,  5, 10,  3,  5,  4,
        7,  4,  2]

# %%
len(visits), len(sum_purchases)
# Out:
# (20, 20)

# %%
mean_visits = sum(visits) / len(visits)
mean_visits
# Out:
# 5.4

# %%
sum_vistis_and_purchases = sum()
sum_vistis_and_purchases
# Out:
# [(6, 316),
#  (2, 493),
#  (10, 367),
#  (3, 153),
#  (9, 224),
#  (9, 121),
#  (2, 322),
#  (3, 450),
#  (6, 196),
#  (6, 397),
#  (10, 281),
#  (2, 239),
#  (5, 484),
#  (10, 124),
#  (3, 223),
#  (5, 448),
#  (4, 432),
#  (7, 255),
#  (4, 4310),
#  (2, 3524)]

# %%
list(sum_purchases), list(visits)
# Out:
# ([316,
#   493,
#   367,
#   153,
#   224,
#   121,
#   322,
#   450,
#   196,
#   397,
#   281,
#   239,
#   484,
#   124,
#   223,
#   448,
#   432,
#   255,
#   4310,
#   3524],
#  [6, 2, 10, 3, 9, 9, 2, 3, 6, 6, 10, 2, 5, 10, 3, 5, 4, 7, 4, 2])

# %%
cov_purchases_and_visits = [(sum_purchases[x] - mean_purchases) * (visits[x] - mean_visits) for x in range (len(sum_purchases))]
cov_purchases_and_visits = sum(cov_purchases_and_visits) / (len(sum_purchases) -1)
cov_purchases_and_visits
# Out:
# -990.1368421052633

# %%
sqr_visits_minus_mean = [(i - mean_visits)**2 for i in visits]
sqr_visits_minus_mean

std_purchases = (sum(sqr_sum_minus_mean) / (len(sum_purchases) - 1)) ** 0.5
std_visits = (sum(sqr_visits_minus_mean) / (len(visits) - 1)) ** 0.5
std_purchases, std_visits
# Out:
# (1124.5433447451132, 2.9091507170885533)

# %%
pearson_coeff = cov_purchases_and_visits / (std_purchases*std_visits)
pearson_coeff
# Out:
# -0.30265844687666454

# %%
np.cov(sum_purchases, visits, bias=False)
# Out:
# array([[ 1.26459773e+06, -9.90136842e+02],
#        [-9.90136842e+02,  8.46315789e+00]])

# %%
np.corrcoef(sum_purchases, visits)
# Out:
# array([[ 1.        , -0.30265845],
#        [-0.30265845,  1.        ]])

# %%
pearson_correlation = np.cov(sum_purchases, visits, bias=False)/ (np.std(sum_purchases, ddof=1) * np.std(visits, ddof=1))
pearson_correlation
# Out:
# array([[ 3.86553828e+02, -3.02658447e-01],
#        [-3.02658447e-01,  2.58696184e-03]])

# %%
import matplotlib.pyplot as plt

plt.scatter(sum_purchases, visits)
plt.title('Scatter Plot of Purchases vs. Visits')
plt.xlabel('Sum of Purchases')
plt.ylabel('Number of Visits');

# %% [markdown]
# In our data set we might identify and delete outliers in order to show linearity of point on the graph.

# %%
sum_purchases_cleaned = [i for i in sum_purchases if i < 1000]
np.corrcoef(sum_purchases_cleaned, visits[:len(sum_purchases_cleaned)])
# Out:
# array([[ 1.        , -0.36852121],
#        [-0.36852121,  1.        ]])

# %%
import seaborn as sns

plt.scatter(sum_purchases_cleaned, visits[:len(sum_purchases_cleaned)])
sns.regplot(x=sum_purchases_cleaned, y=visits[:len(sum_purchases_cleaned)], scatter=False, color='red')
plt.title('Scatter Plot of Purchases vs. Visits')
plt.xlabel('Sum of Purchases')
plt.ylabel('Number of Visits');

# %% [markdown]
# **Завдання 7**. В попередньому завданні ми помітили, що викиди нам заважають отримати "правдиве" значення кореляції. Давайте вилучимо записи, які відповідають значенням з викидами в сумі покупок і обчисліть коеф. кореляції. Для цього поставте `threshold`, який дорінює середньому значенню + 2 стандартних вдіхилля суми покупок і всі значення, які більше за нього, будемо вважати викидами (є і інші правила для визначення викидів - з ним и познайомимось пізніше).
#
# Вилучіть значення з обох масивів і обчисліть коеф. кореляції Пірсона з допомогою `numpy` для кількості візитів і суми покупок без записів-викидів. Виведіть результат на екран, побудуйте діаграму розсіювання і проаналізуйте результат: що можемо сказати про залежність в даних?

# %%
threshold = mean_purchases + 2 * std_purchases

# %%
data_cleaned = zip(sum_purchases, visits)

sum_purchases_cleaned2 = []
visits_cleaned = []

for i, k in data_cleaned:
    if i <threshold:
        sum_purchases_cleaned2.append(i)
        visits_cleaned.append(k)

np.corrcoef(sum_purchases_cleaned2, visits_cleaned)
# Out:
# array([[ 1.        , -0.36852121],
#        [-0.36852121,  1.        ]])

# %%
plt.scatter(sum_purchases_cleaned2, visits_cleaned)
sns.regplot(x=sum_purchases_cleaned, y=visits_cleaned, scatter=False, color='red')
plt.title('Scatter Plot of Purchases vs. Visits')
plt.xlabel('Sum of Purchases')
plt.ylabel('Number of Visits');

# %% [markdown]
# Negative correlation as the sum of purchases goes up, the number of visits decreases. The relationship between data points is relatively weak, suggesting that there's negative skewness, probably skewed to the left
# Meaning: people more often do small purchases rather than big ones
