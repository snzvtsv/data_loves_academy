# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd

# %%
df.head(20)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428      A     Yangon        Member  Female
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 2   631-41-3108      A     Yangon        Normal    Male
# 3   123-19-1176      A     Yangon        Member    Male
# 4   373-73-7910      A     Yangon        Normal    Male
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 7   315-22-5665      C  Naypyitaw        Normal  Female
# 8   665-32-9167      A     Yangon        Member  Female
# 9   692-92-5582      B   Mandalay        Member  Female
# 10  351-62-0822      B   Mandalay        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
# 13  252-56-2699      A     Yangon        Normal    Male
# 14  829-34-3910      A     Yangon        Normal  Female
# 15  299-46-1805      B   Mandalay        Member  Female
# ...

# %%
df = pd.read_csv('/Users/s1ndly/Data Analytics/data/supermarket_sales.csv')

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.groupby('Branch')['gross income'].sum()
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %% [markdown]
# Branch C (Naypyitaw)has the highest gross income at $5265.1765
#
# However, Branch A (Yangon) shows the highest gross margin %, which is a major indicator of profitability.
# As data indicates, Branch C has higher cogs, which, in  turn, impacts the gross margin %. Therefore, my suggestion would be to consider cities Yangon and Mandalay. as there have highers returns.

# %%
df.groupby(['Branch', 'City'])['gross income'].sum()
# Out:
# Branch  City
# A       Yangon       5057.1605
# B       Mandalay     5057.0320
# C       Naypyitaw    5265.1765
# Name: gross income, dtype: float64

# %%
df.groupby(['Branch', 'City'])['cogs'].sum()
# Out:
# Branch  City
# A       Yangon       101143.21
# B       Mandalay     101140.64
# C       Naypyitaw    105303.53
# Name: cogs, dtype: float64

# %%
df.groupby(['Branch', 'City'])['gross margin percentage'].sum()
# Out:
# Branch  City
# A       Yangon       1619.047619
# B       Mandalay     1580.952381
# C       Naypyitaw    1561.904762
# Name: gross margin percentage, dtype: float64

# %%
df.pivot_table(index='City', columns='Branch', values='gross income', aggfunc='sum', fill_value='None')
# Out:
# Branch             A         B          C
# City
# Mandalay        None  5057.032       None
# Naypyitaw       None      None  5265.1765
# Yangon     5057.1605      None       None

# %%
df.pivot_table(index='City', columns='Branch', values='cogs', aggfunc='sum', fill_value='None')
# Out:
# Branch             A          B          C
# City
# Mandalay        None  101140.64       None
# Naypyitaw       None       None  105303.53
# Yangon     101143.21       None       None

# %%
df.pivot_table(index='City', columns='Branch', values='gross margin percentage', aggfunc='sum', fill_value='None')
# Out:
# Branch               A            B            C
# City
# Mandalay          None  1580.952381         None
# Naypyitaw         None         None  1561.904762
# Yangon     1619.047619         None         None

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = df.pivot_table(values='Invoice ID', index='Branch', columns='Product line', aggfunc='count')
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
invoices_by_category.groupby('Branch')['Electronic accessories'].max()[:1]
# Out:
# Branch
# A    60
# Name: Electronic accessories, dtype: int64

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %%
df_woman = df[df.Gender == 'Female']
df_woman.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 6  Electronic accessories       68.84         6  20.6520  433.6920  2/25/2019
# 7      Home and lifestyle       73.56        10  36.7800  772.3800  2/24/2019
# 8       Health and beauty       36.26         2   3.6260   76.1460  1/10/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df_man = df[df.Gender == 'Male']
df_man.head()
# Out:
#      Invoice ID Branch       City Customer type Gender  \
# 2   631-41-3108      A     Yangon        Normal   Male
# 3   123-19-1176      A     Yangon        Member   Male
# 4   373-73-7910      A     Yangon        Normal   Male
# 5   699-14-3026      C  Naypyitaw        Normal   Male
# 11  529-56-3974      B   Mandalay        Member   Male
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 2       Home and lifestyle       46.33         7  16.2155  340.5255
# 3        Health and beauty       58.22         8  23.2880  489.0480
# 4        Sports and travel       86.31         7  30.2085  634.3785
# 5   Electronic accessories       85.39         7  29.8865  627.6165
# 11  Electronic accessories       25.51         4   5.1020  107.1420
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 2    3/3/2019  13:23  Credit card  324.31                 4.761905
# 3   1/27/2019  20:33      Ewallet  465.76                 4.761905
# ...

# %%
df_man_with_hour.pivot_table(values='Time', index='Product line', columns='City', aggfunc=['max', 'min'])
# Out:
#                             max                       min
# City                   Mandalay Naypyitaw Yangon Mandalay Naypyitaw Yangon
# Product line
# Electronic accessories    20:57     20:37  20:54    10:38     10:02  10:46
# Fashion accessories       20:52     20:54  20:06    11:45     10:00  10:00
# Food and beverages        20:03     20:37  20:35    10:37     10:02  10:16
# Health and beauty         20:03     20:44  20:35    10:11     10:30  10:12
# Home and lifestyle        20:38     20:59  20:07    10:26     10:11  10:16
# Sports and travel         20:08     19:49  20:19    10:11     10:17  10:03

# %%
df_woman_with_hour.pivot_table(values='Time', index='Product line', columns='City', aggfunc=['max', 'min'])
# Out:
#                             max                       min
# City                   Mandalay Naypyitaw Yangon Mandalay Naypyitaw Yangon
# Product line
# Electronic accessories    20:51     20:51  20:59    10:17     10:23  10:17
# Fashion accessories       20:42     20:30  18:20    10:33     10:06  10:11
# Food and beverages        20:55     20:39  20:48    10:38     10:17  10:00
# Health and beauty         20:43     19:57  20:36    10:38     10:18  10:05
# Home and lifestyle        20:24     20:50  19:48    10:39     10:13  10:09
# Sports and travel         19:35     19:54  20:34    10:01     10:01  10:18

# %%
df_woman_with_hour.pivot_table(values='Quantity', index='Product line', columns='City', aggfunc=['count'])
# Out:
#                           count
# City                   Mandalay Naypyitaw Yangon
# Product line
# Electronic accessories       28        28     28
# Fashion accessories          33        35     28
# Food and beverages           29        38     23
# Health and beauty            20        23     21
# Home and lifestyle           22        25     32
# Sports and travel            30        29     29

# %%
df_man_with_hour.pivot_table(values='Quantity', index='Product line', columns='City', aggfunc=['count'])
# Out:
#                           count
# City                   Mandalay Naypyitaw Yangon
# Product line
# Electronic accessories       27        27     32
# Fashion accessories          29        30     23
# Food and beverages           21        28     35
# Health and beauty            33        29     26
# Home and lifestyle           28        20     33
# Sports and travel            32        16     30

# %%
time = '11:28'



get_hour(time)
get_hour = lambda t: int(t[:2])

df_woman['Hour'] = df_woman.Time.apply(lambda t: int(t[:2]))
df_woman_with_hour = df_woman.copy()

df_man['Hour'] = df_man.Time.apply(lambda t: int(t[:2]))
df_man_with_hour = df_man.copy()


df['Hour'] = df.Time.apply(lambda t: int(t[:2]))
df = df.copy()
# Out:
# /var/folders/18/v6tsqf5s6tn983tw5hm40jb00000gn/T/ipykernel_8728/2526048007.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_woman['Hour'] = df_woman.Time.apply(lambda t: int(t[:2]))
# /var/folders/18/v6tsqf5s6tn983tw5hm40jb00000gn/T/ipykernel_8728/2526048007.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_man['Hour'] = df_man.Time.apply(lambda t: int(t[:2]))

# %%
date = '3/21/2019'

get_date = lambda d: int(d[:1])


df['Month'] = df.Date.apply(lambda d: int(d[:1]))
df = df.copy()

# %%
df.tail(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender            Product line  Unit price  Quantity   Tax 5%      Total       Date   Time      Payment    cogs  gross margin percentage  gross income  Rating  Hour  Month
# 990  886-18-2897      A     Yangon        Normal  Female      Food and beverages       56.56         5  14.1400   296.9400  3/22/2019  19:06  Credit card  282.80                 4.761905       14.1400     4.5    19      3
# 991  602-16-6955      B   Mandalay        Normal  Female       Sports and travel       76.60        10  38.3000   804.3000  1/24/2019  18:10      Ewallet  766.00                 4.761905       38.3000     6.0    18      1
# 992  745-74-0715      A     Yangon        Normal    Male  Electronic accessories       58.03         2   5.8030   121.8630  3/10/2019  20:46      Ewallet  116.06                 4.761905        5.8030     8.8    20      3
# ...

# %%
df_man_with_hour.head()
# Out:
#      Invoice ID Branch       City Customer type Gender            Product line  Unit price  Quantity   Tax 5%     Total       Date   Time      Payment    cogs  gross margin percentage  gross income  Rating  Hour
# 2   631-41-3108      A     Yangon        Normal   Male      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card  324.31                 4.761905       16.2155     7.4    13
# 3   123-19-1176      A     Yangon        Member   Male       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet  465.76                 4.761905       23.2880     8.4    20
# 4   373-73-7910      A     Yangon        Normal   Male       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet  604.17                 4.761905       30.2085     5.3    10
# ...

# %%
df_woman2.pivot_table(values='Quantity', index='Product line', columns='City', aggfunc=['count', 'max', 'min'])
# Out:
#                           count                       max                   \
# City                   Mandalay Naypyitaw Yangon Mandalay Naypyitaw Yangon
# Product line
# Electronic accessories       28        28     28       10        10     10
# Fashion accessories          33        35     28       10        10     10
# Food and beverages           29        38     23       10        10     10
# Health and beauty            20        23     21       10        10     10
# Home and lifestyle           22        25     32       10        10     10
# Sports and travel            30        29     29       10        10     10
#
#                             min
# City                   Mandalay Naypyitaw Yangon
# Product line
# Electronic accessories        1         1      1
# Fashion accessories           1         1      1
# Food and beverages            1         1      1
# Health and beauty             1         1      1
# Home and lifestyle            1         1      1
# ...

# %%
df_pivoted = df.pivot_table(values=['Quantity'], index=['Product line', 'Gender'], columns=['City'], aggfunc=['count', 'max', 'min', 'mean'])
df_pivoted
# Out:
#                                  count                       max            \
#                               Quantity                  Quantity
# City                          Mandalay Naypyitaw Yangon Mandalay Naypyitaw
# Product line           Gender
# Electronic accessories Female       28        28     28       10        10
#                        Male         27        27     32       10        10
# Fashion accessories    Female       33        35     28       10        10
#                        Male         29        30     23       10        10
# Food and beverages     Female       29        38     23       10        10
#                        Male         21        28     35       10        10
# Health and beauty      Female       20        23     21       10        10
#                        Male         33        29     26       10        10
# Home and lifestyle     Female       22        25     32       10        10
# ...

# %%
df_pivoted2 = df.pivot_table(values=['Unit price'], index=['Product line', 'Gender'], columns=['City'], aggfunc=['max', 'min', 'mean'])
df_pivoted2
# Out:
#                                      max                         min  \
#                               Unit price                  Unit price
# City                            Mandalay Naypyitaw Yangon   Mandalay
# Product line           Gender
# Electronic accessories Female      99.73     99.69  99.56      10.59
#                        Male        91.56     96.82  99.55      18.93
# Fashion accessories    Female      97.61     99.30  99.10      14.48
#                        Male        99.89     99.82  98.98      17.49
# Food and beverages     Female      99.69     99.42  99.60      17.63
#                        Male        93.40     99.79  99.78      18.08
# Health and beauty      Female      99.71     99.19  95.95      13.50
#                        Male        99.16     99.96  99.83      10.75
# Home and lifestyle     Female      97.38     89.25  96.52      11.28
#                        Male        99.92     97.50  97.94      13.59
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df_products = df.pivot_table(index=['Product line', 'Customer type', 'Gender'], columns=['City'], values=['Quantity'], aggfunc=['count', 'max', 'mean']).round(2)
df_products
# Out:
#                                                count                   \
#                                             Quantity
# City                                        Mandalay Naypyitaw Yangon
# Product line           Customer type Gender
# Electronic accessories Member        Female       14         9     12
#                                      Male         13        11     19
#                        Normal        Female       14        19     16
#                                      Male         14        16     13
# Fashion accessories    Member        Female       16        19     12
#                                      Male         16        13     10
#                        Normal        Female       17        16     16
#                                      Male         13        17     13
# Food and beverages     Member        Female       18        23     10
#                                      Male         11        13     19
# ...

# %%
df_naypyitaw = df[(df['City'] == 'Naypyitaw') & (df['Product line'] == 'Electronic accessories') & (df['Gender'] == 'Female')]
unit_price_comparison = df_naypyitaw.groupby('Customer type')['Unit price'].mean()
print(unit_price_comparison)
# Out:
# Customer type
# Member    62.961111
# Normal    49.801579
# Name: Unit price, dtype: float64

# %%
product_analysis = df.groupby(['Customer type', 'Product line']).agg({'Quantity': 'mean', 'Total': 'mean'})
print(product_analysis)
# Out:
#                                       Quantity       Total
# Customer type Product line
# Member        Electronic accessories  5.500000  314.083269
#               Fashion accessories     5.104651  306.092581
#               Food and beverages      5.382979  333.591702
#               Health and beauty       5.863014  353.849856
#               Home and lifestyle      5.903614  337.084663
#               Sports and travel       5.666667  324.532190
# Normal        Electronic accessories  5.891304  324.337353
#               Fashion accessories     5.032609  304.151446
#               Food and beverages      5.575000  309.840300
#               Health and beauty       5.392405  295.730373
#               Home and lifestyle      5.467532  336.154364
#               Sports and travel       5.405063  340.361089

# %%
df[df['Product line'] == 'Electronic accessories'].groupby(['City', 'Customer type', 'Gender'])[['Unit price']].agg(['mean', 'max', 'min', 'std']).round(2)
# Out:
#                                Unit price
#                                      mean    max    min    std
# City      Customer type Gender
# Mandalay  Member        Female      44.19  93.96  10.59  29.94
#                         Male        53.07  91.56  18.93  25.31
#           Normal        Female      51.16  99.73  13.78  28.80
#                         Male        51.22  87.08  21.58  23.99
# Naypyitaw Member        Female      62.96  98.84  30.20  22.31
#                         Male        66.18  96.82  12.05  29.57
#           Normal        Female      49.80  99.69  12.45  25.31
#                         Male        51.79  96.37  11.81  27.79
# Yangon    Member        Female      55.32  94.64  17.42  25.37
#                         Male        54.98  93.78  11.94  28.95
#           Normal        Female      53.79  99.56  15.69  25.54
#                         Male        55.63  99.55  10.56  30.47

# %%
df.groupby(['City', 'Product line', 'Customer type','Gender'])['Unit price'].agg(['mean']).round(2)
# Out:
#                                                         mean
# City      Product line           Customer type Gender
# Mandalay  Electronic accessories Member        Female  44.19
#                                                Male    53.07
#                                  Normal        Female  51.16
#                                                Male    51.22
#           Fashion accessories    Member        Female  46.98
#                                                Male    57.38
#                                  Normal        Female  53.11
#                                                Male    63.68
#           Food and beverages     Member        Female  57.66
#                                                Male    53.13
#                                  Normal        Female  65.65
#                                                Male    43.25
#           Health and beauty      Member        Female  45.37
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# %%
df_products_time = df.pivot_table(index=['Product line', 'Customer type'], columns=['City'], values=['Time'], aggfunc=['max', 'min'])
df_products_time
# Out:
#                                           max                       min
#                                          Time                      Time
# City                                 Mandalay Naypyitaw Yangon Mandalay Naypyitaw Yangon
# Product line           Customer type
# Electronic accessories Member           20:32     20:51  20:54    10:17     11:21  10:17
#                        Normal           20:57     20:36  20:59    10:34     10:02  10:18
# Fashion accessories    Member           20:13     20:08  19:30    11:16     10:36  10:00
#                        Normal           20:52     20:54  20:06    10:33     10:00  10:12
# Food and beverages     Member           20:55     20:39  20:35    10:37     10:17  10:00
#                        Normal           20:43     20:37  20:48    10:48     10:02  10:16
# Health and beauty      Member           20:24     20:44  20:33    10:11     10:30  11:03
# ...

# %%
df[df['Customer type'] == 'Member'].pivot_table(index=['Product line', 'Customer type'], columns=['City'], values=['Quantity'], aggfunc=['sum'], margins=True)
# Out:
#                                           sum
#                                      Quantity
# City                                 Mandalay Naypyitaw Yangon   All
# Product line           Customer type
# Electronic accessories Member             147       120    162   429
# Fashion accessories    Member             143       163    133   439
# Food and beverages     Member             160       193    153   506
# Health and beauty      Member             172       127    129   428
# Home and lifestyle     Member             137       143    210   490
# Sports and travel      Member             165       151    177   493
# All                                       924       897    964  2785

# %%
df_time_analysis = df.groupby('Customer type')['Hour'].agg(['mean', 'median', 'max', 'min']).round(2)
df_time_analysis
# Out:
#                 mean  median  max  min
# Customer type
# Member         14.97    15.0   20   10
# Normal         14.85    15.0   20   10

# %%
gender_analysis = df[df['Product line'] == 'Fashion accessories'].groupby(['Gender', 'City'])[['Quantity', 'Unit price', 'Total']].agg(['mean']).round(2)
pd.DataFrame(gender_analysis)
# Out:
#                  Quantity Unit price   Total
#                      mean       mean    mean
# Gender City
# Female Mandalay      5.36      50.14  275.20
#        Naypyitaw     5.49      57.20  329.13
#        Yangon        5.75      59.79  351.29
# Male   Mandalay      4.14      60.20  252.82
#        Naypyitaw     5.00      62.69  334.68
#        Yangon        4.43      52.88  282.45

# %% [markdown]
# 1. Normal-type customers are buying higher quantity of Electronic Accessories than Members in Naypyitaw city (and even aacross all the cities). The mean price for Members is 62.96$, while for Normal is $49.80, meaning that Normal customers are bulk-buying products in this category, whereas Members are buying lower quantities, but paying a premium price.
#
# Naypyitaw -> Electronic Accessories: Female - 9 (Member), 19 (Normal)
# Min price - 30.20 (member), 12.45 (normal)
#
# If Members have higher purchasing power, then the business could utilise it in a way of expanding its product range to offer more luxury items and adjusting marketing campaign to target wealthier individuals.
#
# 2. Do Normal customers tend to shop earlier in the day compared to Members?
# Member	14.97
# Normal	14.85
#
# This confirms the hypothesis. Therefore, the business may offer promotions targeted at Normal cusotmers in order to increase sales volume.
#
# 3. Do female customers prefer buying more items in the 'Fashion accessories' category compared to male customers?
#
# Female
#
# Mandalay	5.36
# Naypyitaw	5.49
# Yangon	5.75
#
# Male
# Mandalay	4.14
# Naypyitaw	5.00
# Yangon	4.43
#
# Action: Sign up for more collaborationd with celebrities or bloggers to increase attention
